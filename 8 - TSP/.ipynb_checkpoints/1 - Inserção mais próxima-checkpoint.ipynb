# %% [markdown]
# # Inserção mais próxima
# Na inserção mais próxima, inserimos os vértices ao caminho sendo percorrido comparando o custo da inserção desse vértice na solução parcial:
# ### Exemplo
#
# #### Inicialização
# * O vértice inicial é escolhido aleatoriamente
# * **Vértice escolhido:** A
# * Depois encontre o vértice com menor custo a partir do vértice inicial e construa o ciclo parcial:
#
# Ciclo parcial: **A-D-A**
#
# <img src="./Imagens/exemplo1.png" style='width:50%'>
#    Para inserir um novo vértice no ciclo seguimos os seguintes passos:
#     <ul>
#         <li>Comparamos o custo da inserção das arestas ainda não presentes no caminho.</li>
#         <li>O vértice inicial é o vértie A. </li>
#         <li>Os vértices já visitados são A e D.</li>
#         <li>Fazemos a seguinte comparação, para econtrar o menor custo.</li>
#         <ul>
#             <li>custo<sub>(i, k)</sub> + custo<sub>(k, j)</sub> - custo<sub>(i, j)</sub> </li>
#         </ul>
#     </ul>
#     <ul>
#         <li>Sendo</li>
#         <ul>
#             <li>i - vértice A</li>
#             <li>j - vertice D</li>
#             <li>k - vértices C e B</li>
#         </ul>
#     </ul>
# <table>
#     <tr>
#         <td style='width: 33.33%; vertical-align:top; font-size:16px; border: 4px solid black; background-color:white;'>
#             custo<sub>(i, k)</sub> + custo<sub>(k, j)</sub> - custo<sub>(i, j)</sub> = 24 + 3 - 1 = 26.
#         </td>
#         <td style='width: 33.33%; vertical-align:top; font-size:16px; border: 4px solid black; background-color:white;'>
#             custo<sub>(i, k)</sub> + custo<sub>(k, j)</sub> - custo<sub>(i, j)</sub> = 56 + 25 - 1 = 80.
#         </td>
#         <td style='width: 33.34%; vertical-align:top; font-size:16px; border: 4px solid black; background-color:white;'>
#             Inserimos <i>k</i> no ciclo, entre <i>i</i> e <i>j</i>. <b>A - C - D -A</b>.
#         </td>
#     </tr>
#     <tr>
#         <td><img src="./Imagens/exemplo2.png"></td>
#         <td><img src="./Imagens/exemplo3.png"></td>
#         <td><img src="./Imagens/exemplo4.png"></td>
#     </tr>
# </table>

# %% [markdown]
# ### Demonstração do funcionamento do algoritmo:

# %% [markdown]
# <table>
#     <tr>
#         <td style='width: 33%; vertical-align:top; font-size:16px; border: 4px solid black; background-color:white;'>
#          Dado um grafo G(V, E).
#         </td>
#         <td style='width: 33%; vertical-align:top; font-size:16px; border: 4px solid black; background-color:white;'>
#          Primeiro escolhemos um vértice inicial qualquer de forma aleatória.
#         </td>
#         <td style='width: 33%; vertical-align:top; font-size:16px; border: 4px solid black; background-color:white;'>
#             A partir do vértice inicial escolhemos a aresta de menor peso. Criando um ciclo, que começa e termina no vértice inicial: 1 - 5 -1.
#         </td>
#     </tr>
#     <tr>
#         <td><img src="./Imagens/TSP.png"></td>
#         <td><img src="./Imagens/TSPIMP0.png"></td>
#         <td><img src="./Imagens/TSPIMP1.png"></td>
#     </tr>
#  </table>
# <div style='width: 100%; vertical-align:top; font-size:16px; border: 4px solid black; background-color:white;'>
#  No algoritmo de inserção mais próxima, sempre procuramos uma aresta para inserir no ciclo parcial sendo formado que gere o menor custo, para tanto procuramos arestas ligadas aos vértices já visitados da seguinte maneira:<ol><li>analisamos o custo da inserção de todas arestas possíveis</li><li>escolhemos a aresta que ao ser inserida ao caminho irá gerar o menor custo.</li></ol>
# </div>
# <table>
#     <tr>
#         <td><img src="./Imagens/TSPIMP2.png"></td>
#         <td><img src="./Imagens/TSPIMP3.png"></td>
#         <td><img src="./Imagens/TSPIMP4.png"></td>
#     </tr>
# </table>
#
# <img src="./Imagens/TSPIMP5.png" style="width:33%">

# %% [markdown]
# # Código

# %%
import random
from math import inf
# Grafo no formato de matriz de adjacência
grafo = [[0, 7, 1, 15, 8, 3],
         [7, 0, 9, 21, 5, 4],
         [1, 9, 0, 35, 26, 12],
         [15, 21, 35, 0, 13, 42],
         [8, 5, 26, 13, 0, 5],
         [3, 4, 12, 42, 5, 0]]

ciclo = []

def insercao_tsp():
    visitado = [] # guarda vertices ja visitados
    if grafo:
        v1 = random.randint(0, len(grafo)-1) # um vertice e escolhido aleatoriamente no grafo
        visitado.append(v1)
        ciclo.append(v1) # adicionamos o vértice inicial ao ciclo
        print(grafo)
        while len(visitado) < len(grafo): # a execucao do algoritmo só encerrada quando todos os vertices forem adicionados ao ciclo
            indice, vertice_a_ser_inserido = find_min(visitado) # i recebe o indice onde o vertice v sera inserido no ciclo, e j recebe o vertice a ser inserido no ciclo
            if indice == 0: # i retorna 0 quando ha apenas o primeiro vértice no ciclo
                ciclo.extend([vertice_a_ser_inserido, ciclo[0]]) # adicionamos v ao ciclo e o vertice inicial, ja que temos que retornar ao ponto de partida.
            else:
                ciclo.insert(indice, vertice_a_ser_inserido) # inserimos a nova aresta no local que gera o menor custo
            visitado.append(vertice_a_ser_inserido)
            print("ciclo parcial:", ciclo)
    print("ciclo final:", ciclo)
    print("ordem de visitação:", visitado)

def find_min(visitado):
    '''
    Encontra a aresta de menor custo e local onde inseri-la no ciclo 
    Parametro:
        visitado
            lista que contem todos os vertices ja visitados            
    '''
    # primeiro econtramos a aresta de menor valor


    n = 0 # n representa o indice dos vertices ja visitados
    i = 0 # recebe o vertice visitado[n]
    j = 0 # recebe o vertice visitado[n+1]
    indice = 0 #retorna o indice onde o novo vertice sera introduzido no ciclo
    vertice_a_ser_inserido = 0 
    custo = 0 # recebe o resultado do calculo do custo de adicionar um novo vertice no ciclo parcial
    menor = inf # guarda o menor custo encontrado a partir da insercao dos vertices nao visitados
    if len(visitado) >= 2:
        while n < len(visitado)-1:
            i = visitado[n]
            j = visitado[n + 1]
            for k in range(len(grafo)): # k representa o vertice a ser inserido
                if i != j and i != k and k != j and k not in visitado : # quando i, j e k sao iguais a distancia e igual a zero
                    custo = grafo[i][k] + grafo[k][j] - grafo[i][j]
                    if custo < menor:
                        menor = custo
                        indice = visitado.index(j) 
                        vertice_a_ser_inserido = k
            n += 1
        print("custo: {}, vertice a ser inserido: {} ".format(custo, vertice_a_ser_inserido))
                
    else:
        if visitado:
            tmp = grafo[visitado[0]]
            tmp[visitado[0]] = inf
            vertice_a_ser_inserido = tmp.index(min(tmp))
            indice = 0
    return indice, vertice_a_ser_inserido



insercao_tsp()
# Out:
# [[0, 7, 1, 15, 8, 3], [7, 0, 9, 21, 5, 4], [1, 9, 0, 35, 26, 12], [15, 21, 35, 0, 13, 42], [8, 5, 26, 13, 0, 5], [3, 4, 12, 42, 5, 0]]
# ciclo parcial: [4, 1, 4]
# custo: 4, vertice a ser inserido: 5
# ciclo parcial: [4, 5, 1, 4]
# custo: 59, vertice a ser inserido: 0
# ciclo parcial: [4, 5, 0, 1, 4]
# custo: 54, vertice a ser inserido: 2
# ciclo parcial: [4, 5, 0, 2, 1, 4]
# custo: 49, vertice a ser inserido: 3
# ciclo parcial: [4, 3, 5, 0, 2, 1, 4]
# ciclo final: [4, 3, 5, 0, 2, 1, 4]
# ordem de visitação: [4, 1, 5, 0, 2, 3]
