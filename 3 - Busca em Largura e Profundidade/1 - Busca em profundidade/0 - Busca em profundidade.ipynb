# %% [markdown]
# # Busca em Profundidade

# %% [markdown]
# Busca em profundidade ou DFS(Depth-First Search) é um algoritmo de caminhamento em grafos que pode ser usado para detectar ciclos, componentes fortemente conexas, vértices não alcançáveis e também realizar ordenação topológica.
#
# Para explorar o grafo utilizando a busca em profundidade, visitamos todos os vértices do grafo apenas uma vez. Esses vértices são marcados de acordo com a ordem de visitação.
#
# Realizar a busca em profundidade é como mapear um labirinto. A partir de um ponto inicial, escolhemos um caminho para seguir, memorizamos o caminho de ida, como voltar e ao voltar ao ponto que iniciamos, até ter explorado todos os pontos possíveis.
#
# A busca em profundidade pode ser feita em quaisquer tipos de grafos.

# %% [markdown]
# ## Exemplo:
# <img src="./Imagens/BuscaProfundidade.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Iniciaremos a busca em profundidade pelo vértice A:
# * Marcamos o vértice como explorado(cinza);
# * Verificamos suas adjacências;
# * Escolhemos um caminho de acordo com algum critério, aqui utilizaremos ordem alfabética.
#
# <img src="./Imagens/BuscaProfundidade1.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Escolhemos o vértice B:
#
# * Marcamos o vértice como explorado(cinza);
# * Verificamos suas adjacências;
# * O único caminho possível é o vértice D:
#
#
# <img src="./Imagens/BuscaProfundidade2.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Vamos para o vértice D:
#
# * Marcamos o vértice como explorado(cinza);
# * Verificamos suas adjacências;
# * O único caminho possível é o vértice C:
#
#
# <img src="./Imagens/BuscaProfundidade3.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Vamos para o vértice C:
#
# * Marcamos o vértice como explorado(cinza);
# * Verificamos suas adjacências;
#
# <img src="./Imagens/BuscaProfundidade4.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# * Podemos ver que todos os vértices adjacentes a C já foram explorados
# * O vértice é marcado com visitado(preto);
# * Fazemos o backtracking, verificando os vértices anteriores na ordem contrária que foram explorados.
#
# <img src="./Imagens/BuscaProfundidade5.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# * O vértice D não possui mais vértices adjacentes não explorados.
# * Fechamos o vértice D:
#
# <img src="./Imagens/BuscaProfundidade6.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# * O vértice B não possui mais vértices adjacentes não explorados.
# * Fechamos o vértice B:
#
# <img src="./Imagens/BuscaProfundidade7.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# * O vértice A não possui mais vértices adjacentes não explorados.
# * Fechamos o vértice A:
#
# <img src="./Imagens/BuscaProfundidade8.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# * Vamos para outro vértice ainda não explorado, continuando por ordem alfabética.
# * Vamos para o vértice E:
#
# <img src="./Imagens/BuscaProfundidade9.png" style="width:50%; margin-left:auto; margin-right:auto;">
# Novamente:
#
# * Verificamos adjacências;
# * Escolhemos o próximo vértice a ser explorado;
# * Vamos para o vértice H:
#
#
# <img src="./Imagens/BuscaProfundidade_10.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Existem dois caminhos possíveis a partir do vértice H, por ordem alfabética, escolhemos o vértice I:
#
# <img src="./Imagens/BuscaProfundidade_11.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Do vértice I vamos para o vértice F:
#
# <img src="./Imagens/BuscaProfundidade_12.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# De F para G:
#
# <img src="./Imagens/BuscaProfundidade_13.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Ao chegarmos em G, podemos perceber não existem vértices adjacentes a G.
#
# * Fechamos o vértice G(preto) e fazemos o backtracking:
#
# <img src="./Imagens/BuscaProfundidade_14.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# * O vértice F não possui mais vértices adjacentes não explorados.
# * Fechamos o vértice F:
#
# <img src="./Imagens/BuscaProfundidade_15.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# * O vértice I não possui mais vértices adjacentes não explorados.
# * Fechamos o vértice I:
#
# <img src="./Imagens/BuscaProfundidade_16.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Ao chegar no vértice H, verificamos que o vértice J ainda não foi explorado,
#
# * Exploramos J:
#
#
# <img src="./Imagens/BuscaProfundidade_17.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Todos os vértices adjacentes a J já foram explorados e/ou visitados. Logo, fechamos J
#
# <img src="./Imagens/BuscaProfundidade_18.png" style="width:50%; margin-left:auto; margin-right:auto;">
# <img src="./Imagens/BuscaProfundidade_19.png" style="width:50%; margin-left:auto; margin-right:auto;">
#
# Continuamos o backtracking até o vértice E, e então não temos mais vértices para explorar.
#
# <img src="./Imagens/BuscaProfundidade_20.png" style="width:50%; margin-left:auto; margin-right:auto;">
# <img src="./Imagens/RepresentaçãoDFSTree.png" style="width:50%; margin-left:auto; margin-right:auto;" >

# %% [markdown]
# ## Tipos de arestas

# %% [markdown]
# <img src="./Imagens/TiposDeArestas.png" style="width:70%; margin-left:auto; margin-right:auto">
#
# * Aresta de árvore - aresta que liga os vértices das árvores geradas pela execução do algorimo de busca em profundidade.
#
# <img src="./Imagens/arestaDeArvore.png" style="width:40%; margin-left:auto; margin-right:auto">
#
# * Aresta cruzada - é uma aresta a partir de um vértice _u_ a um vértice _v_ onde as subárvores ligadas a _u_ e _v_ são distintas.
#
# <img src="./Imagens/arestaCruzada.png" style="width:40%; margin-left:auto; margin-right:auto">
#
# * Aresta direta - uma aresta direta é uma aresta que parte de um vértice a um de seus descendentes que está na mesma subárvore, mas não é uma aresta de árvore.
#
# <img src="./Imagens/arestaDireta.png" style="width:40%; margin-left:auto; margin-right:auto">
#
# * Aresta de retorno - uma aresta de retorno é uma aresta que parte de um vértice a um de seus antecessores.
#
# <img src="./Imagens/arestaDeRetorno.png" style="width:40%; margin-left:auto; margin-right:auto">

# %% [markdown]
# ## Pseudocódigo
# <pre>
# 1. DFS(G):
# 2.    for each vertex u E G.V
# 3.        u.color = WHITE
# 4.        u.pi = NIL
# 5.    time = 0
# 6.    for each vertex u E G.V
# 7.        if u.color == WHITE
# 8.            DFS-Visit(G, u)
#
# 9.    DFS-Visit(G, u):
# 10.        time = time + 1
# 11.        u.d = time
# 12.        u.color = GRAY
# 13.        for each v E G.Adj[u]
# 14.            if v.color == WHITE
# 15.                v.pi = u
# 16.                DFS-Visit(G, v)
# 17.        u.color = BLACK
# 18.        time = time + 1
# 19.        u.f = time
#
# G.V - conjunto de vértices
# pi - vértice pai
# d - tempo de descoberta
# f - tempo em que o vértice é fechado, torna-se preto e não é mais explorado
# </pre>

# %% [markdown]
# *  Os vértices do grafo G são inicializados com a cor BRANCO, vértice pai: NIL
# *  A variável tempo é inicializado com 0.
# *  A busca em profundidade é feita na ordem em que os vértices aparecem no conjunto G.V. Essa ordem não importa, desde que contenha todos os vértices.
# *  Na busca em profundidade, exploramos todo ciclo ou floresta desde o vértice inicial até o último vértice alcançável a partir do vértice inicial.
#
#     **DFS-Visit**
# * Ao explorar um vértice acrescemos o tempo em uma unidade, o tempo de descoberta é atribuído ao vértice.
# * O vértice recebe a cor cinza.
# * Todos os vértices alcançáveis são explorados.
# * Os vértices são fechados (tornam-se pretos) quando não há mais vértices adjacentes para serem visitados.

# %% [markdown]
# # Código

# %%
## DFS

# variável com o controle de tempo de descoberta e fechamento do vértice
tempo = 0
# lista que contém o status de cada vértice (Branco, Cinza, Preto), assim como o vértice pai e o tempo
grafo_dfs = []
# lista que contém os vértices que já foram visitados
visitado = []

def DFS(Grafo):
    '''
    Função para inicializar os valores como: cor, pai, tempo
    Parâmetros:
        Grafo
            grafo a ser percorrido pela busca em profundidade
    '''
    # Inicialização de valores
    for i in list(Grafo.keys()):
        grafo_dfs.append([i, 'BRANCO', None])
    global tempo
    tempo = 0
    
    # percorre o conjunto de vértices
    for i in range(len(list(Grafo.keys()))):
        # caso o vertice nao tenha sido visitado, e realizada a busca em profundidade(teste para todos os vertices)
        if grafo_dfs[i][0] not in visitado:
            DFS_Visit(Grafo, grafo_dfs[i][0])

def DFS_Visit(Grafo, u):
    '''
    Função que realiza a busca em profundidade em cada ciclo/floresta de todos os vértices alcançaveis a partir de u.
        Parâmetros:
            Grafo
                Grafo a ser percorrido
            u
                vértice inicial não visitado
    '''
    # tempo de descoberta do vértice
    global tempo
    tempo += 1    
    
    # encontrando o indice do vertice u no grafo_dfs
    for i in range(len(grafo_dfs)):
        if grafo_dfs[i][0] == u:
            indice = i

    # O vértice sendo explorado, recebe a cor cinza, o tempo de descoberta
    grafo_dfs[indice][1] = 'CINZA'
    grafo_dfs[indice].append(("tempo de descoberta:", tempo))
    visitado.append(grafo_dfs[indice][0])
    #print("visitado: ", visitado)
    
    # variavel que recebera o indice do proximo vertice a ser visitado
    ind = 0
    # buscamos vertices adjacentes a u que nao tenham sido visitados ainda (BRANCOS)
    for v in Grafo[u]:        
        for i in range(len(grafo_dfs)):
            if v == grafo_dfs[i][0] and v not in visitado:
                ind = i
             
        # Ao encontrar vertices adjacentes nao visitados, continuamos a busca recursivamente  
        if grafo_dfs[ind][1] == 'BRANCO':
            grafo_dfs[ind][2] = u
            DFS_Visit(Grafo, v)
    # Ao nao ter mais vertice para explorar o vertice e fechado (torna-se preto) e recebe o tempo em que 
    # foi fechado
    for i in range(len(grafo_dfs)):
        if grafo_dfs[i][0] == u:
            grafo_dfs[i][1] = 'PRETO'
            tempo += 1
            grafo_dfs[i].append(('tempo2:' , tempo))
   
lista_adjacencia = {
    1: {2: 4, 5: 9, 6: 8},
    2: {1: 4, 3: 6, 4: 6, 7: 12},
    3: {2: 6, 6: 23, 5: 11, 7: 55},
    4: {2: 6, 5: 99, 6: 46, 7: 19},
    5: {1: 9, 3: 11, 4: 99},
    6: {1: 8, 3: 23, 4: 46, 10: 9},
    7: {2: 12, 3: 55, 4: 19},
    8: {9: 4},
    9: {8: 4},
    10: {6: 9}
}


DFS(lista_adjacencia)
for i in grafo_dfs:
    print("grafo:", i)
# Out:
# grafo: [1, 'PRETO', None, ('tempo de descoberta:', 1), ('tempo2:', 16)]
# grafo: [2, 'PRETO', 1, ('tempo de descoberta:', 2), ('tempo2:', 15)]
# grafo: [3, 'PRETO', 2, ('tempo de descoberta:', 3), ('tempo2:', 14)]
# grafo: [4, 'PRETO', 6, ('tempo de descoberta:', 5), ('tempo2:', 10)]
# grafo: [5, 'PRETO', 4, ('tempo de descoberta:', 6), ('tempo2:', 7)]
# grafo: [6, 'PRETO', 3, ('tempo de descoberta:', 4), ('tempo2:', 13)]
# grafo: [7, 'PRETO', 4, ('tempo de descoberta:', 8), ('tempo2:', 9)]
# grafo: [8, 'PRETO', None, ('tempo de descoberta:', 17), ('tempo2:', 20)]
# grafo: [9, 'PRETO', 8, ('tempo de descoberta:', 18), ('tempo2:', 19)]
# grafo: [10, 'PRETO', 6, ('tempo de descoberta:', 11), ('tempo2:', 12)]

# %% [markdown]
# ***Diferente da busca em largura, a busca em profundidade é realizada em todo o grafo, mesmo ele sendo desconexo.***

# %%
## obs: para executar essa célula é necessário antes executar células anteriores respectivas ao código

import networkx as nx
import matplotlib.pyplot as plt

#NetworkX
Grafo = nx.Graph()
edges = []
for i, j in lista_adjacencia.items():
    adj = list(j)
    for k in range(len(j)):
        edges.append((i,adj[k]))

Grafo.add_nodes_from(lista_adjacencia.keys())
Grafo.add_edges_from(edges)

nx.draw(Grafo, with_labels=True, font_weight='bold')
plt.show()
