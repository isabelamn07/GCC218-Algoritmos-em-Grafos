# %% [markdown]
# # Algoritmo de Bellman-Ford

# %% [markdown]
# No algoritmo de Bellman-Ford encontramos o caminho mínimo a partir de um vértice inicial **s(source)**, em relação a todos os outros vértices do grafo. Para tanto, realizamos |V|-1 iterações onde a cada iteração relaxamos as arestas buscando sempre as menores distâncias/valores.

# %% [markdown]
# Inicializamos todas as distâncias/pesos e vértices pai com infinito e um valor nulo(tabela), respectivamente

# %% [markdown]
# 1. Inicializamos todas as distâncias/pesos e vértices pai com infinito e um valor nulo(tabela), respectivamente
#
#
# <table>
#     <tr>
#         <td>
#             <img src="Imagens/Bellman-Ford.png" style="width:300px; height:300px;">
#         </td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr>
#                     <td>T</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#                 <tr>
#                     <td>Y</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#                 <tr>
#                     <td>X</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#                 <tr>
#                     <td>Z</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Ordem das arestas: **(S, T), (S, Y), (T, X), (T, Y), (T, Z), (X, T), (Y, X), (Y, Z), (Z, S), (Z, X).**

# %% [markdown]
# O vértice S recebe distância 0 e por ser o vértice inicial não possui vértice pai.
# 1. Primeira aresta **(S, T)**
# 2. A aresta **(S, T)** tem peso 6.
# 3. Atualizamos o valor atual que é infinito com o valor 6 na tabela de caminho mínimo.

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford2.png"  style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>6</td>
#                     <td>S</td>
#                 </tr>
#                 <tr>
#                     <td>Y</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#                 <tr>
#                     <td>X</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#                 <tr>
#                     <td>Z</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. Aresta **(S, Y)**
# 2. Aresta **(S, Y)** = 7
# 3. Atualizamos a tabela com o valor 7.

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford3.png"  style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>6</td>
#                     <td>S</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr>
#                     <td>X</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#                 <tr>
#                     <td>Z</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. Par de vértices **(T, X)**
# 2. **(S, T) + (T, X)** = 6 + 5 = 11
# 3. Atualizamos a tabela com o caminho mínimo de **S** a **X** com o novo valor 11 que é menor que infinito.

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford4.png"  style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>6</td>
#                     <td>S</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>11</td>
#                     <td>T</td>
#                 </tr>
#                 <tr>
#                     <td>Z</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. Para de vértices: (T, Y)
# 2. (S, T) + (T, Y) = 6 + 8 = 14.
# 3. Na tabela de caminho mínimo a distância de S a Y atual é 7, 14 é maior que 7, então não atualizamos a tabela.

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford5.png"  style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>6</td>
#                     <td>S</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>11</td>
#                     <td>T</td>
#                 </tr>
#                 <tr>
#                     <td>Z</td>
#                     <td>inf</td>
#                     <td>None</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. Par de vértices: **(T, Z)**
# 2. **(S, T) + (T, Z)** = 6 - 4 = 2.
# 3. 2 é menor que infinito, portanto atualizamos na tabela de caminho miínimo.

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford6.png"  style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>6</td>
#                     <td>S</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>11</td>
#                     <td>T</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>2</td>
#                     <td>T</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. Par de vértices: **(X, T)**
# 2. Caminho: **S-T-X-T**
# 3. **(S, T) + (T, X) + (X, T)** = 6 + 5 -2 = 9
# 4. O valor do caminho atual de S até T é 6.
# 5. 9 é maior que 6, então não modificamos nada na tabela de caminho mínimo.

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford7.png"  style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>6</td>
#                     <td>X</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>11</td>
#                     <td>T</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>2</td>
#                     <td>T</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. Par de vértices: **(Y, X)**
# 2. Caminho **S-Y-Z**
# 3. **(S, Y) + (Y, X)** = 7 - 3 = 4.
# 4. 4 é menor que o valor atual na tabela do caminho mínimo que é 11.
# 5. Atualizamos a tabela.

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford8.png"  style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>6</td>
#                     <td>X</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>4</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>2</td>
#                     <td>T</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. Par de vértices: **(Y, Z)**
# 2. Caminho: **S-Y-X-T-Z**

# %% [markdown]
# <table>
#     <tr>
#         <td>
#             <img src="Imagens/Bellman-Ford8.1.png" style="width:300px; height:300px;">
#         </td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>2</td>
#                     <td>X</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>4</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>-2</td>
#                     <td>T</td>
#                 </tr>
#             </table>
#         </td>
#         <td>
#             <img src="Imagens/Bellman-Ford9.png" style="width:300px; height:300px;">
#         </td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>2</td>
#                     <td>X</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>4</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>-2</td>
#                     <td>T</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="Imagens/Bellman-Ford10.png" style="width:300px; height:300px;"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>2</td>
#                     <td>X</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>4</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>-2</td>
#                     <td>T</td>
#                 </tr>
#             </table>
#         </td>
#         <td>
#             <img src="Imagens/Bellman-Ford11.png" style="width:300px; height:300px;"">
#         </td>
#         <td>
#             <table>
#                 <tr>
#                     <th>Vértice</th>
#                     <th>Distância</th>
#                     <th>Pai</th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>None</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>2</td>
#                     <td>X</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>7</td>
#                     <td>S</td>
#                 </tr>
#                 <tr  style = "color:red">
#                     <td>X</td>
#                     <td>4</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>-2</td>
#                     <td>T</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # Código

# %%
from math import inf

'''
BELLMAN-FORD(G, w, s)
1 INITIALIZE-SINGLE-SOURCE(G, s)
2 for i = 1 to |G.V| - 1
3   for each edge (u, v) pertence a G:E
4       RELAX(u, v, w)
5   for each edge (u, v) pertence a G:E
6       if v.d => u.d + w(u, v)
7           return FALSE
8 return TRUE

INITIALIZE-SINGLE-SOURCE(G, s)
1 for each vertex v pertence a G.V
2   v.d = inf 
3   v.pi = NIL
4 s.d = 0

RELAX(u, v, w)
1 if v.d > u.d + w(u, v)
2   v.d = u.d + w(u,v)
3   v.pi = u

'''
single_source = []
def bellman_ford(grafo_bf):
    vertices = list(grafo_bf.keys())
    for i in grafo.keys():
        single_source.append([i, inf, None])

    single_source[0][1] = 0

    print("Single source: ", single_source)
    for i in range(1, len(grafo.keys())+1, 1):
        for x in grafo.keys():
            for y in grafo[x]:
                relax(x, y)
    for i in grafo_bf.keys(): #Retorna True se houver ciclos negativos
        for j in grafo_bf[i]:
            if single_source[vertices.index(j)][1] > single_source[vertices.index(i)][1] + grafo_bf[i][j]:
                return False
    return True
              
    

def relax(u, v):
    if single_source[vertices.index(v)][1] > \
        single_source[vertices.index(u)][1] + grafo[u][v]:
        single_source[vertices.index(
            v)][1] = single_source[vertices.index(u)][1] + grafo[u][v]
        single_source[vertices.index(
            v)][2] = u

        print(single_source)


grafo = {'s':{'t':6, 'y':7},
         't':{'x':5, 'y':8, 'z':-4},
         'x':{'t':-2},
         'y':{'x': -3, 'z':9},
         'z':{'s':2, 'x': 7}         
         }
vertices = list(grafo.keys())
print(bellman_ford(grafo))
# Out:
# Single source:  [['s', 0, None], ['t', inf, None], ['x', inf, None], ['y', inf, None], ['z', inf, None]]
# [['s', 0, None], ['t', 6, 's'], ['x', inf, None], ['y', inf, None], ['z', inf, None]]
# [['s', 0, None], ['t', 6, 's'], ['x', inf, None], ['y', 7, 's'], ['z', inf, None]]
# [['s', 0, None], ['t', 6, 's'], ['x', 11, 't'], ['y', 7, 's'], ['z', inf, None]]
# [['s', 0, None], ['t', 6, 's'], ['x', 11, 't'], ['y', 7, 's'], ['z', 2, 't']]
# [['s', 0, None], ['t', 6, 's'], ['x', 4, 'y'], ['y', 7, 's'], ['z', 2, 't']]
# [['s', 0, None], ['t', 2, 'x'], ['x', 4, 'y'], ['y', 7, 's'], ['z', 2, 't']]
# [['s', 0, None], ['t', 2, 'x'], ['x', 4, 'y'], ['y', 7, 's'], ['z', -2, 't']]
# True
