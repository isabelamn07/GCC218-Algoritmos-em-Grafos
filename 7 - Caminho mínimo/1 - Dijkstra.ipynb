# %% [markdown]
# ### Algoritmo de Dijkstra
#
# O Algoritmo de Dijkstra encontra o menor caminho entre os vértices a partir de um vértice inicial **S**.
#
# ### Exemplo:
#
# Inicialmente todas as distâncias/valores recebem infinito, e todos vértices pai recebem valor nulo.
# <table>
#     <tr style ="background-color: white">
#         <td><img src="Imagens/Dijkstra.png" style="height:300px; width:300px"></td>
#     <td>
#     <table>
#     <tr text-align:"center">
#         <th><b>Vértice</b></th>
#         <th><b>Distância</b></th>
#         <th><b>Vértice Pai</b></th>
#     </tr>
#     <tr>
#         <td>S</td>
#         <td>infinito</td>
#         <td>Null</td>
#     </tr>
#     <tr>
#         <td>T</td>
#         <td>infinito</td>
#         <td>Null</td>
#     </tr>
#     <tr>
#         <td>Y</td>
#         <td>infinito</td>
#         <td>Null</td>
#     </tr>
#     <tr>
#         <td>Z</td>
#         <td>infinito</td>
#         <td>Null</td>
#     </tr>
#     <tr>
#         <td>X</td>
#         <td>infinito</td>
#         <td>Null</td>
#     </tr>
# </table>
#     </td>
#     </tr>
#     </table>

# %% [markdown]
# 1. Escolhemos o vértice inical **S**.
# 2. Como estamos procurando o caminho mínimo a partir de **S**, sua distância é **0**
# <table>
#     <tr style ="background-color: white">
#         <td><img src="Imagens/Dijkstra1.png" style="height:300px; width:300px"></td>
#         <td><table>
#                <tr>
#                    <th><b>Vértice</b></th>
#                    <th><b>Distância</b></th>
#                 <th><b>Vértice Pai</b></th>
#                 </tr>
#                 <tr style="color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>Null</td>
#                 </tr>
#                 <tr>
#                     <td>T</td>
#                     <td>infinito</td>
#                     <td>Null</td>
#                     </tr>
#                 <tr>
#                     <td>Y</td>
#                     <td>infinito</td>
#                     <td>Null</td>
#                 </tr>
#                 <tr>
#                     <td>Z</td>
#                     <td>infinito</td>
#                     <td>Null</td>
#                 </tr>
#                 <tr>
#                     <td>X</td>
#                     <td>infinito</td>
#                     <td>Null</td>
#                     </tr>
#         </table></td>
# </tr>
# </table>

# %% [markdown]
# 1. **S** tem como vértices adjacentes os vértices **T** e **Y**.
# 2. A aresta **(S, T)** tem peso 10.
# 3. Comparamos os valores das distâncias.
# 4. O valor atual da distância entre **S** e **T** é infinito.
# 5. Comparamos o valor atual da tabela, com o valor da aresta **(S, T)**.
# 6. Sempre escolhemos o menor valor para atualizar a tabela, portanto atualizamos a tabela com o valor **10**.
# 7. A aresta **(S, Y)** tem peso 5.
# 8. Comparamos os valores de distância.
# 9. O valor atual da distância entre **S** e **Y** é infinito.
# 10. Se 5 for menor que infinito(valor atual).
# 11. Atualizamos a tabela.
#
# <table>
# <tr style ="background-color: white">
# <td><img src="Imagens/Dijkstra2.png" style="height:300px; width:300px"></td>
# <td><table>
#     <tr>
#         <th><b>Vértice</b></th>
#         <th><b>Distância</b></th>
#         <th><b>Vértice Pai</b></th>
#     </tr>
#     <tr style = "color:red">
#         <td>S</td>
#         <td>0</td>
#         <td>Null</td>
#     </tr>
#     <tr style = "color:red">
#         <td>T</td>
#         <td>10</td>
#         <td>S</td>
#     </tr>
#     <tr style = "color:red">
#         <td>Y</td>
#         <td>5</td>
#         <td>S</td>
#     </tr>
#     <tr>
#         <td>Z</td>
#         <td>infinito</td>
#         <td>Null</td>
#     </tr>
#     <tr>
#         <td>X</td>
#         <td>infinito</td>
#         <td>Null</td>
#     </tr>
#     </table></td>
#     </tr>
# </table>

# %% [markdown]
# 1. **S** é marcado como visitado.
# 2. Como ordem de visitação estamos sempre escolhendo o vértice que tem menor distância na tabela e que ainda não foi visitado.
# 3. Portanto escolhemos **Y**.
# 4. **Y** tem como vértices adjacentes **T**, **X** e **Z**.
# 5. Comparamos os valores das distâncias uma a uma, agora também atualizando as distâncias dos vértices adjacentes a **Y**.
# 6. O valor atual da distância entre **S** e **T** é 10
# 7. Somamos o valor do novo caminho **S-Y-T**
# 8. **(S, Y)** + **(Y, T)** ou 5 + 3 = 8
# 9. Comparamos os valores.
# 10. **S-Y-T = 8** é menor que o atual valor **S-T = 10**?
# 11. Se sim, atualizamos a tabela.
# 12. A aresta **(S, Y)** tem peso 5 e sua distância não se altera.
# 13. O valor atual da distância entre **S** e **Z** é infinito.
# 14. Fazemos a comparação
# 15. **(S, Y) + (Y, Z)** ou 5 + 2 = 7.
# 16. Se 7 for menor que o valor atual da tabela que é infinito.
# 17. Atualizamos a distância de **Z** na tabela.
# 18. O valor atual da distância entre **S** e **X** é infinito.
# 19. Fazemos a comparação
# 20. **(S, Y) + (Y, X)** ou 5 + 9 = 14.
# 21. Se 14 for menor que o valor atual da tabela que é infinito.
# 22. Atualizamos a distância de **Z** na tabela.
#
# <table>
#     <tr style ="background-color: white">
#         <td>
#             <img src="Imagens/Dijkstra3.png" style="height:300px; width:300px">
#         </td>
#         <td>
#             <table>
#                 <tr>
#                     <th><b>Vértice</b></th>
#                     <th><b>Distância</b></th>
#                     <th><b>Vértice Pai</b></th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>Null</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>8</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>5</td>
#                     <td>S</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>7</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>X</td>
#                     <td>14</td>
#                     <td>Y</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. **Y** é marcado como visitado.
# 2. Próximo vértice a ser explorado é o **Z**.
# 3. **Z** é adjacente a **S e X**
# 4. **S-Y-Z-S = (S, Y) + (Y, Z) + (Z, S)** = 5 + 2 + 7 = 14
# 5. Distância atual de **S = 0, S-Y-Z** = 14.
# 6. Não atulizamos os valores pois, não haveria redução na distância.
# 7. **S-Y-Z-X = (S, Y) + (Y, Z) + (Z, X)** = 5 + 2 + 6 = 13
# 8. Distância atual de **X = 14, S-Y-Z-X = 13**.
# 9. Atualizamos a distância de **S** até **X**, pois conseguimos diminui-la.
#
# <table>
#     <tr style ="background-color: white">
#         <td><img src="Imagens/Dijkstra4.png" style="height:300px; width:300px"></td>
#         <td>
#             <table>
#                 <tr>
#                     <th><b>Vértice</b></th>
#                     <th><b>Distância</b></th>
#                     <th><b>Vértice Pai</b></th>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>S</td>
#                     <td>0</td>
#                     <td>Null</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>T</td>
#                     <td>8</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Y</td>
#                     <td>5</td>
#                     <td>S</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>Z</td>
#                     <td>7</td>
#                     <td>Y</td>
#                 </tr>
#                 <tr style = "color:red">
#                     <td>X</td>
#                     <td>13</td>
#                     <td>Z</td>
#                 </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# 1. **Z** é marcado como visitado.
# 2. Próximo vértice a ser explorado é o **T**.
# 3. **T** é adjacente a **X e Y.**
# 4. **S-Y-Z-S = (S, Y) + (Y, Z) + (Z, S)** = 5 + 2 + 7 = 14
# 5. Distância atual de **S** = 0, **S-Y-Z** = 13.
# 6. Não atualizamos a distância de S na tabela pois o valor atual é menor.
# 7. **S-Y-T-X = (S, Y) + (Y, T) + (T, X)** = 5 + 3 + 1 = 9
# 8. Distância atual de **X** = 13, **S-Y-T-X** = 9.
# 9. Atualizamos a distância de **S** até **X**, pois conseguimos reduzir a distância.

# %% [markdown]
# <table>
# <tr style ="background-color: white">
# <td><img src="Imagens/Dijkstra5.png" style="height:300px; width:300px"></td>
# <td><table>
#     <tr>
#         <th><b>Vértice</b></th>
#         <th><b>Distância</b></th>
#         <th><b>Vértice Pai</b></th>
#     </tr>
#     <tr style = "color:red">
#         <td>S</td>
#         <td>0</td>
#         <td>Null</td>
#     </tr>
#     <tr style = "color:red">
#         <td>T</td>
#         <td>8</td>
#         <td>Y</td>
#     </tr>
#     <tr style = "color:red">
#         <td>Y</td>
#         <td>5</td>
#         <td>S</td>
#     </tr>
#     <tr style = "color:red">
#         <td>Z</td>
#         <td>7</td>
#         <td>Y</td>
#     </tr>
#     <tr style = "color:red">
#         <td>X</td>
#         <td>9</td>
#         <td>T</td>
#     </tr>
#     </table></td>
#     </tr>
# </table>

# %% [markdown]
# 1. T é marcado como visitado
# 2. Vértice explorado: X
# 3. **X** é adjacente a **Z**.
# 4. **(X, Z)** = 4
# 5. **S-Y-T-X-Z = (S, Y) + (Y, T) + (T, X)** + **(X, Z)** = 5 + 3 + 1 + 4 = 9.
# 6. O valor atual da tabela é 7.
# 7. Não conseguimos reduzir o valor, então mantemos o valor atual.

# %% [markdown]
# <table>
# <tr style ="background-color: white">
# <td><img src="Imagens/Dijkstra6.png" style="height:300px; width:300px"></td>
# <td><table>
#     <tr>
#         <th><b>Vértice</b></th>
#         <th><b>Distância</b></th>
#         <th><b>Vértice Pai</b></th>
#     </tr>
#     <tr style = "color:red">
#         <td>S</td>
#         <td>0</td>
#         <td>Null</td>
#     </tr>
#     <tr style = "color:red">
#         <td>T</td>
#         <td>8</td>
#         <td>Y</td>
#     </tr>
#     <tr style = "color:red">
#         <td>Y</td>
#         <td>5</td>
#         <td>S</td>
#     </tr>
#     <tr style = "color:red">
#         <td>Z</td>
#         <td>7</td>
#         <td>Y</td>
#     </tr>
#     <tr style = "color:red">
#         <td>X</td>
#         <td>9</td>
#         <td>T</td>
#     </tr>
#     </table></td>
#     </tr>
# </table>

# %% [markdown]
# ### Caminho mínimo
# Finalizamos a execução do algoritmo depois de visitar todos os vértices
#
# <table>
# <tr style ="background-color: white">
# <td><img src="Imagens/Dijkstra7.png" style="height:300px; width:300px"></td>
# <td><table>
#     <tr>
#         <th><b>Vértice</b></th>
#         <th><b>Distância</b></th>
#         <th><b>Vértice Pai</b></th>
#     </tr>
#     <tr style = "color:red">
#         <td>S</td>
#         <td>0</td>
#         <td>Null</td>
#     </tr>
#     <tr style = "color:red">
#         <td>T</td>
#         <td>8</td>
#         <td>Y</td>
#     </tr>
#     <tr style = "color:red">
#         <td>Y</td>
#         <td>5</td>
#         <td>S</td>
#     </tr>
#     <tr style = "color:red">
#         <td>Z</td>
#         <td>7</td>
#         <td>Y</td>
#     </tr>
#     <tr style = "color:red">
#         <td>X</td>
#         <td>9</td>
#         <td>T</td>
#     </tr>
#     </table></td>
#     </tr>
# </table>

# %% [markdown]
# <h2>Pseudocódigo</h2>
# <pre>
# DIJKSTRA(G, w, s)
#     1 INITIALIZE-SINGLE-SOURCE(G, s)
#     2 S = vazio
#     3 Q = G.V
#     4 while Q != vazio
#     5   u = EXTRACT-MIN(Q)
#     6   S = S U {u}
#     7   for each vertex v pertece a G.Adj[u]
#     8       RELAX(u, v, w)
#
#     INITIALIZE-SINGLE-SOURCE(G, s)
#     1 for each vertex v pertence a G.V
#     2   v.d = inf
#     3   v.pi = NIL
#     4 s.d = 0
#
#     RELAX(u, v, w)
#     1 if v.d > u.d + w(u, v)
#     2   v.d = u.d + w(u,v)
#     3   v.pi = u
# <br>
# G - Grafo
# s - vértice inicial
# w - peso das arestas
# Q - estrutura de dados com todos os vértices a serem visitados
# G.V - Conjunto de todos os vértices
# pi - vértice pai
# d - distância
# S - estrura de dados que contém os vértices visitados
#
# </pre>

# %% [markdown]
# # Código

# %%
from math import inf

visitado = [] # lista que recebe os vértices já visitados
single_source = [] # matriz com o caminho mínimo no formato [[vértice, distância, vértice pai], ...]

def dijkstra_cm(grafo, s):
    '''
    Função que recebe o grafo e o vértice inicial, inicializa os valores da matriz single_source
    e encontra o caminho mínimo
    Parametros:
        grafo
            grafo que procuramos o caminho mínimo
        s
            vértice inicial
    '''
    # inicialização dos valores na matriz single_source
    for i in grafo.keys():
        single_source.append([i, inf, None])
    single_source[0][1] = 0    

    Q = list(grafo.keys()) # lista que recebe o conjunto de todos os vértices
    
    # loop para encontrar o caminho mínimo visitando todos os vértices
    while len(Q) != 0: # enquanto Q não for vazio
        u = extract_min(Q) # u recebe o vértice com menor distância a partir do vértice inicial, que ainda não foi visitado
        Q.remove(u) # após visitado o vértice é removido
        visitado.append(u)
        print("Q:", Q)
        for v in grafo[u]:
            relax(u, v) # funcao que compara valores na matriz single_source para encontrar o menor caminho
    print('single source', single_source)

def extract_min(Q):
    '''
    Funcao que retorna o vertice com menor distancia atribuida que ainda nao foi visitado
    Parametros
        Q
            lista com vertices do grafo que ainda serao visitados
    '''
    menor = inf
    valor = 'x'
    for x in Q:
        if single_source[vertices.index(x)][1] < menor and x not in visitado:
            menor = single_source[vertices.index(x)][1]
            valor = single_source[vertices.index(x)][0]

    visitado.insert(0, valor)
    print('single source', single_source)
    return valor

def relax(u, v):
    '''
    Compara os valores dos caminhos encontrados com os valores de distancia atuais, caso encontre um caminho 
    com distancia menor, atualiza a matriz single_source com a nova distacia
    Parametros
        u 
            vertice do grafo
        v 
            vertice adjacente a u
    '''
    if single_source[vertices.index(v)][1] > \
            single_source[vertices.index(u)][1] + grafo[u][v]:
        single_source[vertices.index(
            v)][1] = single_source[vertices.index(u)][1] + grafo[u][v]
        single_source[vertices.index(
            v)][2] = u

# grafo no formato de lista de adjacência
# grafo = {'s': {'t': 10, 'y': 5},
#          't': {'x': 1, 'y': 2},
#          'x': {'z': 4},
#          'y': {'t':3, 'x': 9, 'z': 2},
#          'z': {'s': 7, 'x': 6}
#          }
grafo = { 'S': {'B': 1, 'D': 3},
          'A': {'C': 9},
          'B': {'A': 5, 'D':12},
          'C': {'B': 7, 'T': 2},
          'D': {'C': 5, 'E': 6, 'F': 2},
          'E': {'C': 4, 'T': 1},
          'F': {'E': 21, 'T': 8}, 
          'T': {}
}
vertices = list(grafo.keys())
dijkstra_cm(grafo, vertices[0])
# Out:
# single source [['S', 0, None], ['A', inf, None], ['B', inf, None], ['C', inf, None], ['D', inf, None], ['E', inf, None], ['F', inf, None], ['T', inf, None]]
# Q: ['A', 'B', 'C', 'D', 'E', 'F', 'T']
# single source [['S', 0, None], ['A', inf, None], ['B', 1, 'S'], ['C', inf, None], ['D', 3, 'S'], ['E', inf, None], ['F', inf, None], ['T', inf, None]]
# Q: ['A', 'C', 'D', 'E', 'F', 'T']
# single source [['S', 0, None], ['A', 6, 'B'], ['B', 1, 'S'], ['C', inf, None], ['D', 3, 'S'], ['E', inf, None], ['F', inf, None], ['T', inf, None]]
# Q: ['A', 'C', 'E', 'F', 'T']
# single source [['S', 0, None], ['A', 6, 'B'], ['B', 1, 'S'], ['C', 8, 'D'], ['D', 3, 'S'], ['E', 9, 'D'], ['F', 5, 'D'], ['T', inf, None]]
# Q: ['A', 'C', 'E', 'T']
# single source [['S', 0, None], ['A', 6, 'B'], ['B', 1, 'S'], ['C', 8, 'D'], ['D', 3, 'S'], ['E', 9, 'D'], ['F', 5, 'D'], ['T', 13, 'F']]
# Q: ['C', 'E', 'T']
# ...
